# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import stats
from scipy.stats import variation
from os import listdir
from os.path import isfile, join
from statsmodels.distributions.empirical_distribution import ECDF
from statsmodels.stats.proportion import proportions_ztest
from collections import defaultdict
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import  Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import mean_squared_error
import matplotlib
import warnings

warnings.simplefilter('ignore')

# Below are the values that are set as default values for the figures in this report.  
font = {'family' : 'monospace',
        'weight' : 'bold',
        'size'   : 15}
matplotlib.rc('font', **font)
sns.set(font_scale = 1.5)

# %matplotlib inline

# %%
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_colwidth", 150)

# %%
import boto3
from sagemaker import get_execution_role
bucket='insightdata-zahra'
data_key = 'DATATOUSEwarehouse_03_14_20forZahra.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

df=pd.read_csv(data_location)

# %%
a
# Out:
#         Survey      id  participant           Survey Code  started  \
# 0            1  103695       345311                 43233     True
# 1            1  103453       345291                 90973     True
# 2            1  114433       345282                 15724     True
# 3            1  110803       345297                 84210     True
# 4            1  112815       345272                 75834     True
# 5            1  114630       345243                 65193    False
# 6            1  106816       345267                 23953     True
# 7            1  114550       345212                 27696    False
# 8            1  103735       345174                 90270     True
# 9            1  106486       345130                 44192     True
# 10           1  114461       345116                 92388     True
# 11           1  105553       345100                 70805     True
# 12           1  114419       345098                 51947     True
# ...

# %%
np.savetxt('data.csv', b, delimiter=',')

boto3.Session().resource('s3').Bucket(bucket).Object('examples').upload_file('data.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1375                 try:
# -> 1376                     v = format % tuple(row) + newline
#    1377                 except TypeError:
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-98fd6331a10b> in <module>()
# ----> 1 np.savetxt('data.csv', b, delimiter=',')
#       2
#       3 boto3.Session().resource('s3').Bucket(bucket).Object('examples').upload_file('data.csv')
#
# ...

# %%
b.to_csv(path_or_buf='s3://insightdata-zahra/test.csv',mode='wb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7063b20a424f> in <module>()
# ----> 1 b.to_csv(path_or_buf='s3://insightdata-zahra/test.csv',mode='wb')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
# ...

# %%
data_location
# Out:
# 's3://insightdata-zahra/DATATOUSEwarehouse_03_14_20forZahra.csv'

# %%
s3://insightdata-zahra/DATATOUSEwarehouse_03_14_20forZahra.csv

# %%
mypathr='../data/raw/'
file_names = 'DATA TO USE warehouse_03_14_20 for Zahra.csv'
file = mypathr+file_names
df=pd.read_csv(file)

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {dtype('bool'): Index(['started'], dtype='object'),
#  dtype('int64'): Index(['Survey', 'id', 'participant', 'ti_1-resources', 'ti_2', 'ti_3',
#         'ti_4-giving extra', 'ti_5-ppl cooperate', 'ti_6', 'ti_7', 'ti_8',
#         'ti_9', 'ti_10', 'ti_11-not just a job', 'ti_12', 'ti_13', 'ti_14',
#         'ti_15-mgt seeks/responds to suggestions', 'ti_16', 'ti_17',
#         'ti_18-informed about imp issues', 'ti_19', 'ti_20', 'ti_21', 'ti_22',
#         'ti_23-contribute to cmmty', 'ti_24-good coordinating of ppl', 'ti_25',
#         'ti_26-psych/emotionally healthy workpl', 'ti_27', 'ti_28',
#         'ti_29-look fwd to coming to work', 'ti_30', 'ti_31', 'ti_32',
#         'ti_33-ppl care about each other', 'ti_34', 'ti_35', 'ti_36',
#         'ti_37-proud to tell others I work here', 'ti_38', 'ti_39', 'ti_40',
#         'ti_41', 'ti_42', 'ti_43-mgt competent', 'ti_44', 'ti_45', 'ti_46',
#         'ti_47-mgt int in me as a person, not just an employee', 'ti_48',
# ...

# %%
df.head()
# Out:
#    Survey      id  participant Survey Code  started  ti_1-resources  ti_2  \
# 0       1  103695       345311       43233     True               4     5
# 1       1  103453       345291       90973     True               5     5
# 2       1  114433       345282       15724     True               0     0
# 3       1  110803       345297       84210     True               5     5
# 4       1  112815       345272       75834     True               4     5
#
#    ti_3  ti_4-giving extra  ti_5-ppl cooperate  ...  Department Code  \
# 0     3                  1                   3  ...              NaN
# 1     5                  5                   5  ...              NaN
# 2     0                  0                   0  ...              NaN
# 3     5                  4                   4  ...              NaN
# 4     4                  4                   4  ...              NaN
#
#    Department Name  Hire Date                Job Title  Region ID  \
# ...

# %%
df.describe()
# Out:
#               Survey             id    participant  ti_1-resources  \
# count  357692.000000  357692.000000  357692.000000   357692.000000
# mean      118.952096  348566.035184  592473.881392        2.390769
# std        64.052365  171298.507837  196470.308034        2.227446
# min         1.000000      31.000000   50466.000000        0.000000
# 25%        70.000000  202772.750000  435831.750000        0.000000
# 50%       122.000000  334185.500000  569923.500000        3.000000
# 75%       186.000000  527634.250000  784568.250000        5.000000
# max       219.000000  626424.000000  921159.000000        5.000000
#
#                 ti_2           ti_3  ti_4-giving extra  ti_5-ppl cooperate  \
# count  357692.000000  357692.000000      357692.000000       357692.000000
# mean        2.515580       2.217399           2.218873            2.191743
# std         2.305769       2.138632           2.120208            2.088734
# ...

# %%
df.columns
# Out:
# Index(['Survey', 'id', 'participant', 'Survey Code', 'started',
#        'ti_1-resources', 'ti_2', 'ti_3', 'ti_4-giving extra',
#        'ti_5-ppl cooperate', 'ti_6', 'ti_7', 'ti_8', 'ti_9', 'ti_10',
#        'ti_11-not just a job', 'ti_12', 'ti_13', 'ti_14',
#        'ti_15-mgt seeks/responds to suggestions', 'ti_16', 'ti_17',
#        'ti_18-informed about imp issues', 'ti_19', 'ti_20', 'ti_21', 'ti_22',
#        'ti_23-contribute to cmmty', 'ti_24-good coordinating of ppl', 'ti_25',
#        'ti_26-psych/emotionally healthy workpl', 'ti_27', 'ti_28',
#        'ti_29-look fwd to coming to work', 'ti_30', 'ti_31', 'ti_32',
#        'ti_33-ppl care about each other', 'ti_34', 'ti_35', 'ti_36',
#        'ti_37-proud to tell others I work here', 'ti_38', 'ti_39', 'ti_40',
#        'ti_41', 'ti_42', 'ti_43-mgt competent', 'ti_44', 'ti_45', 'ti_46',
#        'ti_47-mgt int in me as a person, not just an employee', 'ti_48',
#        'ti_49', 'ti_50-able to take time off when necessary',
# ...
